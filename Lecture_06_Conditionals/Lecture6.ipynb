# %% [markdown]
# # <span style="color:darkblue"> Lecture 6: Lists and Conditionals </span>

# %% [markdown]
# <font size="5">
#
# In the previous class we:
# - Drew random samples with the **`random`** library
# - Installed `scipy` and used the **`binomial`** function
# - See *why* a well-written library function (like the ones in `scipy`) can succeed where a "do-it-yourself" calculation fails

# %% [markdown]
# <font size="5">
#
# In this class we will:
#
# - Learn how to use conditional statements
#   - This will build on lecture 3's comparison and logical operators

# %% [markdown]
# #  <span style="color:darkblue"> I. Conditionals and Flow Control (if/elif/else) </span>
#
# <font size = "5">
#
# - Used to adapt the code to different logical conditions
# - Very helpful when loading, analyzing, and cleaning data!

# %% [markdown]
# <font size = "5">
#
# <table><tr>
# <td> <img src="figures/if.png" alt="drawing" width="250"/>  </td>
# <td>  Running a part of the code <br>
# only if a condition is met: <br>
#
# ``` python
#     if test_expression:
#         <body of if>
# ```
#  </td>
# </tr></table>
#
#
# <font size = "4">
#
# **Test expression**
#
# - We type `if` followed by a logical condition and the `:` (colon) symbol.
# - The `:` indicates that an indented code block is starting
#
# **Body of expression**
#
# - The "body" of the `if` statement needs to be indented
# - You can indent text by pressing the "tab" button on your keyboard.
#
# **If the condition is true, the code in the indented block will be run.**
#
# **If the condition is false, then the indented block is skipped.**

# %%
# Here is one way for a list to "grow" in size

x = [] # empty list
print(x)
x = x + [5] # add 5 to list
print(x)
x = x + [7] # add 7 to list
print(x)

# We will use this approach in the cell below
# Out:
# []
# [5]
# [5, 7]

# %%
good_movies = [] # create empty list

cut_off = 8.0 # minimum rating for "good movie"

# Define variables for 3 movie titles and their corresponding IMDB rating
title_1 = "The Good, the Bad, the Weird"
imdb_rating_1 = 7.2

title_2 = "Citizen Kane" 
imdb_rating_2 = 8.2 

title_3 = "Spider-Man: Across the Spider-Verse" 
imdb_rating_3 = 8.5 

# Determine which movies to add to list

if imdb_rating_1 >= cut_off:
    good_movies = good_movies + [title_1] # add movie to list by concatenation 

if imdb_rating_2 >= cut_off:
    good_movies = good_movies + [title_2] # add movie to list by concatenation 

if imdb_rating_3 >= cut_off:
    good_movies = good_movies + [title_3] # add movie to list by concatenation 


print(good_movies)
# Out:
# ['Citizen Kane', 'Spider-Man: Across the Spider-Verse']

# %% [markdown]
# <font size = "5">
#
# <table><tr>
# <td> <img src="figures/ifelse.png" alt="drawing" width="300"/>  </td>
# <td>  Running two different lines of code <br>
# depending on a condition <br>
#
# ``` python
#     if statement:
#         <body of if>
#     else:
#         <body of else>
# ```
#
#  </td>
# </tr></table>

# %% [markdown]
# <font size = "4">
#
# Now if the statement is `False`, the first code block will be skipped, and the second will be run instead.

# %%
# create empty lists
good_movies = [] 
other_movies = []

cut_off = 8.0 # minimum rating for "good movie"

# Define variables for 3 movie titles and their corresponding IMDB rating
title_1 = "The Good, the Bad, the Weird"
imdb_rating_1 = 7.2 

title_2 = "Citizen Kane" 
imdb_rating_2 = 8.2 

title_3 = "Spider-Man: Across the Spider-Verse" 
imdb_rating_3 = 8.5 


# Divide movies between the two lists

if imdb_rating_1 >= cut_off:
    good_movies = good_movies + [title_1] # add movie to good_movies
else:
    other_movies = other_movies + [title_1] # add movie to other_movies

if imdb_rating_2 >= cut_off:
    good_movies = good_movies + [title_2] 
else:
    other_movies = other_movies + [title_2]

if imdb_rating_3 >= cut_off:
    good_movies = good_movies + [title_3]
else:
    other_movies = other_movies + [title_3]

print(good_movies)
print(other_movies)
# Out:
# ['Citizen Kane', 'Spider-Man: Across the Spider-Verse']
# ['The Good, the Bad, the Weird']

# %% [markdown]
# <font size = "5">
#
# <table><tr>
# <td> <img src="figures/elif.png" alt="drawing" width="300"/>  </td>
# <td>  Running multiple different lines of code <br>
# depending on a series of conditions <br>
#
# ``` python
#     if test_expression_1:
#         <body of if>
#     elif test_expression_2:
#         <body of elif>
#     else:
#         <body of else>
# ```
#
#  </td>
# </tr></table>

# %%
# create empty lists
good_movies = [] 
ok_movies = []
bad_movies = []

cut_off_1 = 8.0 # minimum rating for "good movie"
cut_off_2 = 6.0 # minimum rating for "ok movie"


# Define variables for 3 movie titles and their corresponding IMDB rating
title_1 = "The Good, the Bad, the Weird"
imdb_rating_1 = 7.2 

title_2 = "Citizen Kane" 
imdb_rating_2 = 8.2 

title_3 = "Spider-Man: Across the Spider-Verse" 
imdb_rating_3 = 8.5 

title_4 = "Melania"
imdb_rating_4 = 1.6

# Divide movies between the three lists
# print a warning if we encounter a bad movie

if imdb_rating_1 >= cut_off_1:
    good_movies = good_movies + [title_1] # add movie to good_movies
elif imdb_rating_1 >= cut_off_2:
    ok_movies = ok_movies + [title_1] # add movie to ok_movies
else:
    bad_movies = bad_movies + [title_1] # add movie to bad_movies
    print("Warning! Bad movie alert:", title_1) # ALSO: print warning message

if imdb_rating_2 >= cut_off_1:
    good_movies = good_movies + [title_2]  
elif imdb_rating_2 >= cut_off_2:
    ok_movies = ok_movies + [title_2]
else:
    bad_movies = bad_movies + [title_2]
    print("Warning! Bad movie alert:", title_2)


if imdb_rating_3 >= cut_off_1:
    good_movies = good_movies + [title_3] 
elif imdb_rating_3 >= cut_off_2:
    ok_movies = ok_movies + [title_3]
else:
    bad_movies = bad_movies + [title_3]
    print("Warning! Bad movie alert:", title_3)


if imdb_rating_4 >= cut_off_1:
    good_movies = good_movies + [title_4] 
elif imdb_rating_4 >= cut_off_2:
    ok_movies = ok_movies + [title_4]
else:
    bad_movies = bad_movies + [title_4]
    print("Warning! Bad movie alert:", title_4)


print(good_movies)
print(ok_movies)
print(bad_movies)
# Out:
# Warning! Bad movie alert: Melania
# ['Citizen Kane', 'Spider-Man: Across the Spider-Verse']
# ['The Good, the Bad, the Weird']
# ['Melania']

# %% [markdown]
# # <span style="color:darkblue; font-size:40px"> Exercises</span>

# %% [markdown]
# #### **1)** The cell below defines 3 variables with positive integer values. Write a line of code that uses a comparison operator to determine whether these 3 numbers correspond to the side lengths of a right triangle.
#
# #### Your code should print either `True` or `False` to the screen.

# %%
# are these the side lengths of a right triangle?
a = 3
b = 4
c = 5

# your code here 
print(a**2 + b**2 == c**2)
# Out:
# True

# %% [markdown]
# #### **2)** In Lecture 6, we saw how to create a bar plot using `matplotlib.pyplot.bar`. We generated a bar plot showing the distribution of freshmen, sophomores, juniors, and seniors registered for DATASCI 151 this semester.
#
# #### If we add the `color` argument, we can change the color of the bars, as shown in the code below.

# %%
import matplotlib.pyplot as plt

categories = ["Freshman", "Sophomore", "Junior", "Senior"]

count = [22, 21, 31, 25]

plt.bar(x = categories, height = count, color = "hotpink")
plt.show()

# %% [markdown]
# #### In the cell below, a Boolean variable `is_pink` is defined. Using an if/else statement, write code that generates the bar plot with pink bars when `is_pink` is True. Otherwise, if it is `False` it should display a plot with the default color scheme, like in Lecture 6.
#
# #### Run the code with both `is_pink = False` and `is_pink = True` to make sure it works for both cases.

# %%
is_pink = True

# Your code below
# When is_pink is True, it should create the bar plot with pink columns.
# When is_pink is False, it should create the bar plot with default colors
# Run the cell with is_pink = False and is_pink = True to test that it works

if is_pink == True:
    plt.bar(x = categories, height = count, color = "hotpink")

else:
    plt.bar(x = categories, height = count,)

plt.show()

# %% [markdown]
# #### **3)** Threshold testing a sum
#
# - #### Create a numeric vector (array), $ c = \begin{bmatrix} 1 \\ 2 \\ 3 \end{bmatrix} $
#
# - #### Use the `numpy.sum()` function to add up the individual elements in the array.
#
# - #### If the sum of numbers is greater than or equal to $5$, print a message saying " The sum is greater than or equal to 5"
#
# - #### Otherwise, print the message "It is strictly less than 5"

# %%
# your code here
import numpy as np

c = np.array([1,2,3])

if np.sum(c) >= 5:
    print("This sum is greater than or equal to 5.")

else:
    print("It is strictly less than 5.")
# Out:
# It is strictly less than 5.

# %% [markdown]
# #### **4)** The code cell below generates a random integer between 1 and 20 (both 1 and 20 are possible values).
#
# #### Write code that tests the following:
#
# - #### Tests if the number satisfies $1 \leq n < 5$.
#
# - #### Tests if the number satisfies $5 \leq n \leq 10$
#
# - #### Test if the number satisfies $10 < n < 15$
#
# #### If it satisfies one of the conditions, it prints a message saying which one. If it doesn't satisfy any of the conditions, print a statement saying the number is greater than or equal to 15.

# %%
import random 

lo = 1
hi = 20

random_int = random.randint(lo, hi)
print(random_int)

# your code here

if random_int >= 1 and random_int < 5:
    print("This number is greater than or equal to one and less than five.")

elif random_int >= 5 and random_int <= 10:
    print("This number is greater than or equal to five and less than or equal to ten.")

elif random_int > 10 and random_int < 15:
    print("This number is greater than 10 and less than fifteen.")

else:
    print("This number is greater than or equal to fifteen.")
# Out:
# 10
# This number is greater than or equal to five and less than or equal to ten.

# %% [markdown]
# #### **5)** Repeat the same exercise above with one change: if the number doesn't pass any of the tests, no additional code should be executed.

# %%
import random 

lo = 1
hi = 20

random_int = random.randint(lo, hi)
print(random_int)

# your code here
if random_int >= 1 and random_int < 5:
    print("This number is greater than or equal to one and less than five.")

elif random_int >= 5 and random_int <= 10:
    print("This number is greater than or equal to five and less than or equal to ten.")

elif random_int > 10 and random_int < 15:
    print("This number is greater than 10 and less than fifteen.")
# Out:
# 18

# %% [markdown]
# #### **6)** Do the following:
#
#
# - #### Create a string with your first name (first letter capitalized) and save it to a variable `my_name`
# - #### Turn to a classmate and create a string with their first name (first letter capitalized) and save it to a variable `classmate_name`
# - #### Test whether or not your name is "greater than" your classmate's name. What rule do you think Python uses to determine this?

# %%
# your code here 

my_name = "Jeffery"

classmate_name = "Alex"

print(my_name > classmate_name)
# Out:
# True

# %% [markdown]
# #### **7)** Run the cell below. How do you explain the output you see?

# %%
list_1 = [0, 0, 0, 0, 0]
list_2 = [5, 50, 75, 100, -0.01]
print(list_1 <= list_2)
# Out:
# True

# %% [markdown]
# #  <span style="color:darkblue"> Exercises preparing for the Birthday Paradox next week </span>

# %%
import random

# %%
# Each element is itself a list in the form [name, month, day, year]
birthdays = [
    ["Abed", "March", 23, 2007],
    ["Britta", "July", 14, 1998],
    ["Jeff", "December", 8, 1990],
    ["Shirley", "January", 19, 1990],
    ["Annie", "September", 27, 2007],
    ["Troy", "June", 5, 2007],
    ["Pierce", "December", 30, 1962]]

# %% [markdown]
# <font size = "5">
# Reading a list of lists
# <br>
#
# Each element of `birthdays` is itself a list: `[name, month, day, year]`.
#
# **Before running the cell below**, predict what each line will print. Then run it to check yourself.

# %%
# Run this cell line by line rather than all at once
print(birthdays[0])        # the whole first person ["Abed", "March", 23, 2007]
print(birthdays[0][0])     # just their name Abed
print(birthdays[2][1])     # the month in position 2 December
print(birthdays[6][2])     # the day in position 6 30
print(birthdays[-1])       # the last person ["Pierce", "December", 30, 1962]
print(len(birthdays))      # how many people are in the list? 7
print(len(birthdays[0]))   # how many pieces of info do we store per person? 4
# Out:
# ['Abed', 'March', 23, 2007]
# Abed
# December
# 30
# ['Pierce', 'December', 30, 1962]
# 7
# 4

# %% [markdown]
# <font size = "5">
# Pulling out a birthday
# <br>
#
# - Shirley is the person in position `3`.
# - Store Shirley's month and day in two variables called `shirley_month` and `shirley_day`.
# - Print a sentence describing Jeff's birthday using an f-string.

# %%
shirley_month = birthdays[3][1]
shirley_day   = birthdays[3][2]

print(f"Shirley's birthday is ... {shirley_month} {shirley_day}")
# Out:
# Shirley's birthday is ... January 19

# %% [markdown]
# <font size = "5">
# Birth season
# <br>
#
# - The cell below grabs a random person from `birthdays`
# - Write code that pulls out their month.
# - Using the `in` keyword together with `if` / `elif` / `else`, decide which season that month belongs to and store the answer in a variable called `season`.
#     - Winter: December, January, February
#     - Spring: March, April, May
#     - Summer: June, July, August
#     - Fall: September, October, November
# - Print the result. Try running the cell a few times to make sure it works properly.

# %%
person = random.choice(birthdays)
# Alternatively, we could have randomly selected an index and then use that to select a person from birthdays:
random_index = random.randint(0, len(birthdays)-1)
person = birthdays[random_index]      
month  = person[1]

winter = ["December", "January", "February"]
spring = ["March", "April", "May"]
summer = ["June", "July", "August"]
fall = ["September", "October", "November"]

if month in winter:
    season = winter

elif month in spring:
    season = spring


print(f"{person[0]} was born in {month}, which is in {season}.")

# %% [markdown]
# <font size = "5">
#
# Sometimes old people lie about their age.
#
# In the cell below, write code that selects a random month, day, and year for a person only if they were born before the year 2000.
#  - If a person was born after the year 2000, use the month, day, and year from `birthdays`.
#  - When randomly selecting a year, choose a year between 2000 and 2004.
#  - To make things easier, assume all months have 30 days.

# %%
person = random.choice(birthdays)    
month  = person[1]
day    = person[2]
year   = person[3]



print(f"{person[0]} says they were born {month} {day} {year}.")

# %% [markdown]
# <font size = "5">
#
# Does the code you wrote in the cell above change the month, day, and year values in `birthdays`? If not, how would you write code to change those values?
